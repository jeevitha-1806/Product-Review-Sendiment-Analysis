# %%
import pandas as pd

# %%
df = pd.read_csv("product_reviews.csv")

# %%
print(df)
# Out:
#                      REVIEW SENTIMENT
# 0  The product is excellent  Positive
# 1         Very poor quality  Negative
# 2       I love this product  Positive
# 3        Worst product ever  Negative

# %%
print(df.head())
# Out:
#                      REVIEW SENTIMENT
# 0  The product is excellent  Positive
# 1         Very poor quality  Negative
# 2       I love this product  Positive
# 3        Worst product ever  Negative

# %%
print(df.tail())
# Out:
#                      REVIEW SENTIMENT
# 0  The product is excellent  Positive
# 1         Very poor quality  Negative
# 2       I love this product  Positive
# 3        Worst product ever  Negative

# %%
print(df.shape)
# Out:
# (4, 2)

# %%
print(df.columns)
# Out:
# Index(['REVIEW', 'SENTIMENT'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   REVIEW     4 non-null      object
#  1   SENTIMENT  4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes
# None

# %%
print(df.describe())
# Out:
#                           REVIEW SENTIMENT
# count                          4         4
# unique                         4         2
# top     The product is excellent  Positive
# freq                           1         2

# %%
print(df.dtypes)
# Out:
# REVIEW       object
# SENTIMENT    object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# REVIEW       0
# SENTIMENT    0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df = df.drop_duplicates()
print(df)
# Out:
#                      REVIEW SENTIMENT
# 0  The product is excellent  Positive
# 1         Very poor quality  Negative
# 2       I love this product  Positive
# 3        Worst product ever  Negative

# %%
import pandas as pd

# %%
print(df)
# Out:
#                       Review Sentiments
# 0  The product is excellenct   Positive
# 1          Very poor quality   Negative
# 2        I love this product   Positive
# 3         Woest product ever   Negative

# %%
df.head()
# Out:
#                       Review Sentiments
# 0  The product is excellenct   Positive
# 1          Very poor quality   Negative
# 2        I love this product   Positive
# 3         Woest product ever   Negative

# %%
print(df.columns)
# Out:
# Index(['Review', 'Sentiments'], dtype='object')

# %%
print(df.shape)
# Out:
# (4, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Review      4 non-null      object
#  1   Sentiments  4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
df.describe()
# Out:
#                            Review Sentiments
# count                           4          4
# unique                          4          2
# top     The product is excellenct   Positive
# freq                            1          2

# %%
df.isnull().sum()
# Out:
# Review        0
# Sentiments    0
# dtype: int64

# %%
df.dtypes
# Out:
# Review        object
# Sentiments    object
# dtype: object

# %%
print("Dataset loaded successfully!")
print("Rows:",df.shape[0])
print("Columns:",df.shape[1])
# Out:
# Dataset loaded successfully!
# Rows: 4
# Columns: 2
